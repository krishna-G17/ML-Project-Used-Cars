# %%
import pandas as pd

# %%
df = pd.read_csv("vehicles.csv")

# %%
df.year.head()
# Out:
# 0    2010.0
# 1    2014.0
# 2    2006.0
# 5    2016.0
# 6    2012.0
# Name: year, dtype: float64

# %%
df.shape
# Out:
# (458213, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458213 entries, 0 to 458212
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    458213 non-null  int64
#  1   id            458213 non-null  int64
#  2   url           458213 non-null  object
#  3   region        458213 non-null  object
#  4   region_url    458213 non-null  object
#  5   price         458213 non-null  int64
#  6   year          457163 non-null  float64
#  7   manufacturer  439993 non-null  object
#  8   model         453367 non-null  object
#  9   condition     265273 non-null  object
#  10  cylinders     287073 non-null  object
#  11  fuel          454976 non-null  object
#  12  odometer      402910 non-null  float64
#  13  title_status  455636 non-null  object
#  14  transmission  455771 non-null  object
#  15  VIN           270664 non-null  object
#  16  drive         324025 non-null  object
# ...

# %%
df['year'] = df['year'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-4358701cf1a2> in <module>
# ----> 1 df['year'] = df['year'].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df.isnull().sum() # we tried to find how many missing values are present in the data set!
# Out:
# Unnamed: 0           0
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1050
# manufacturer     18220
# model             4846
# condition       192940
# cylinders       171140
# fuel              3237
# odometer         55303
# title_status      2577
# transmission      2442
# VIN             187549
# drive           134188
# size            321348
# type            112738
# paint_color     140843
# image_url           28
# description         70
# state                0
# lat               7448
# long              7448
# posting_date        28
# dtype: int64

# %%
# df['manufacturer'].nunique() # 43 manufacturers
# df['region'].nunique() # 405 regions
# df['year'].nunique() # 110 year values
# df['model'].nunique() # 31520 models
# df['condition'].nunique() # 6 types of conditioned vehicles
# df['cylinders'].nunique() # 8 types of cylindered vehicles
# df['fuel'].nunique() # 5 types of fuelled vehicles
# df['title_status'].nunique() # 6 types of titled statused vehicles
# df['transmission'].nunique() # 3 types of transmissioned vehicles 
# df['drive'].nunique() # 3 types of driving wheeled vehicles
# df['size'].nunique() # 4 types of vehicles sizes
# df['type'].nunique() # 13 different types of vehicles
# df['paint_color'].nunique() # 12 unique colors
# df['state'].nunique() # # of states listed from
# Out:
# 13

# %%
df['year'].unique()
# Out:
# array([2010., 2014., 2006., 2016., 2012., 2017., 2019., 2013.,   nan,
#        2020., 2018., 2009., 2015., 2004., 2011., 2007., 1990., 2005.,
#        2008., 2003., 1996., 1997., 2000., 1976., 2002., 2001., 1988.,
#        1999., 1993., 1971., 1982., 1962., 1966., 1998., 1995., 1994.,
#        1955., 1967., 1911., 1987., 1969., 1965., 1963., 1991., 1974.,
#        1989., 1984., 1980., 1992., 1975., 1983., 2021., 1961., 1964.,
#        1968., 1973., 1941., 1960., 1986., 1972., 1978., 1936., 1947.,
#        1948., 1979., 1951., 1949., 1970., 1985., 1981., 1977., 1935.,
#        1900., 1933., 1954., 1937., 1930., 1946., 1939., 1956., 1928.,
#        1957., 1950., 1929., 1932., 1959., 1953., 1938., 1940., 1958.,
#        1934., 1924., 1952., 1931., 1926., 1927., 1945., 1942., 1921.])

# %%
df.shape
# Out:
# (458213, 26)

# %%
df.drop_duplicates('VIN',inplace = True)

# %%
df.shape
# Out:
# (133621, 26)

# %%
vehicles_info = df[(df.year>=1995)&(df.year<2021)]

# %%
vehicles_info.shape
# Out:
# (131022, 26)

# %%
vehicles_info.isnull().sum()
# Out:
# Unnamed: 0          0
# id                  0
# url                 0
# region              0
# region_url          0
# price               0
# year                0
# manufacturer     2460
# model             514
# condition       60216
# cylinders       48833
# fuel             1701
# odometer         3177
# title_status     1321
# transmission     1249
# VIN                 1
# drive           28419
# size            94253
# type            18007
# paint_color     31462
# image_url           0
# description        42
# state               0
# lat              1408
# long             1408
# posting_date        0
# dtype: int64

# %%
vehicles = vehicles_info.dropna(how='any', subset=['VIN'])

# %%
vehicles.isnull().sum()
# Out:
# Unnamed: 0          0
# id                  0
# url                 0
# region              0
# region_url          0
# price               0
# year                0
# manufacturer        0
# model             514
# condition       60216
# cylinders           0
# fuel                0
# odometer         3177
# title_status     1321
# transmission        0
# VIN                 0
# drive               0
# size            94252
# type                0
# paint_color     31462
# image_url           0
# description        42
# state               0
# lat              1408
# long             1408
# posting_date        0
# dtype: int64

# %%
vehicles['manufacturer'] = vehicles.manufacturer.fillna(vehicles['model'].map(dup_dict_manuf))
# Out:
# <ipython-input-66-0458d1585b2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['manufacturer'] = vehicles.manufacturer.fillna(vehicles['model'].map(dup_dict_manuf))

# %%
vehicles['type'] = vehicles.type.fillna(vehicles['model'].map(dup_dict_type))
# Out:
# <ipython-input-68-0b9d030d46fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['type'] = vehicles.type.fillna(vehicles['model'].map(dup_dict_type))

# %%
#vehicles['size'] = vehicles['model'].map(dup_dict_size)

for i in vehicles['year']:
    
    

vehicles['size'] = vehicles.size.fillna(vehicles['model'].map(dup_dict_size))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-ad246f19d7e7> in <module>
#       1 #vehicles['size'] = vehicles['model'].map(dup_dict_size)
# ----> 2 vehicles['size'] = vehicles.size.fillna(vehicles['model'].map(dup_dict_size))
#
# AttributeError: 'numpy.int32' object has no attribute 'fillna'

# %%
#vehicles['drive'] = vehicles['model'].map(dup_dict_drive)
vehicles['drive'] = vehicles.drive.fillna(vehicles['model'].map(dup_dict_drive))
# Out:
# <ipython-input-72-2e78e6d4bef2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['drive'] = vehicles.drive.fillna(vehicles['model'].map(dup_dict_drive))

# %%
vehicles['transmission'] = vehicles.transmission.fillna(vehicles['model'].map(dup_dict_trans))
# Out:
# <ipython-input-75-b5480c3cd5bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['transmission'] = vehicles.transmission.fillna(vehicles['model'].map(dup_dict_trans))

# %%
#vehicles['cylinders'] = vehicles['model'].map(dup_dict_cylinders)
vehicles['cylinders'] = vehicles.cylinders.fillna(vehicles['model'].map(dup_dict_cylinders))
# Out:
# <ipython-input-77-e4c0f9e43036>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['cylinders'] = vehicles.cylinders.fillna(vehicles['model'].map(dup_dict_cylinders))

# %%
vehicles['fuel'] = vehicles.fuel.fillna(vehicles['model'].map(dup_dict_fuel))
# Out:
# <ipython-input-80-53ce9d3dff43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['fuel'] = vehicles.fuel.fillna(vehicles['model'].map(dup_dict_fuel))

# %%
dup_vehicles = vehicles.copy()

# %%
dup_vehicles['Manuf_null'] = np.where(dup_vehicles['manufacturer'].isnull(),1,0)

# %%
dup_manuf = dup_vehicles['manufacturer'].copy()

# %%
dup_manuf.isnull().sum()
# Out:
# 2460

# %%
dup_dict_manuf = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_manuf[i] = dup_vehicles['manufacturer']

# %%
dup_vehicles['Manuf'] = dup_vehicles['model'].map(dup_dict)

# %%
# filling the missing values in 'type'
dup_dict_type = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_type[i] = dup_vehicles['type']

# %%
dup_vehicles['typef'] = dup_vehicles['model'].map(dup_dict_type)

# %%
# filling the missing values in 'size'
dup_dict_size = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_size[i] = dup_vehicles['size']

# %%
# filling the missing values in 'drive'
dup_dict_drive = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_drive[i] = dup_vehicles['drive']

# %%
# filling the missing values in 'transmission'
dup_dict_trans = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_trans[i] = dup_vehicles['transmission']

# %%
# filling the missing values in 'cylinders'
dup_dict_cylinders = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_cylinders[i] = dup_vehicles['cylinders']

# %%
# filling the missing values in 'fuel'
dup_dict_fuel = dict()

for i in dup_vehicles['model']:
    if i is not None:
        dup_dict_fuel[i] = dup_vehicles['fuel']

# %%
vehicles[vehicles['odometer'].isnull()]
# Out:
#         Unnamed: 0          id  \
# 2112          2112  7225084638
# 2135          2135  7224778916
# 2142          2142  7224821338
# 3113          3113  7237077910
# 5019          5019  7226691584
# ...            ...         ...
# 457686      457686  7240989977
# 457692      457692  7240982769
# 457707      457707  7240972153
# 457723      457723  7240962219
# 457724      457724  7240961238
#
#                                                       url  \
# 2112    https://bham.craigslist.org/ctd/d/birmingham-2...
# 2135    https://bham.craigslist.org/cto/d/springville-...
# 2142    https://bham.craigslist.org/ctd/d/albertville-...
# 3113    https://huntsville.craigslist.org/cto/d/decatu...
# 5019    https://mobile.craigslist.org/ctd/d/mobile-200...
# ...                                                   ...
# 457686  https://seattle.craigslist.org/skc/ctd/d/aubur...
# 457692  https://seattle.craigslist.org/tac/ctd/d/tacom...
# ...

# %%
vehicles.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer         0
# model              514
# condition        60216
# cylinders            0
# fuel                 0
# odometer        131021
# title_status      1321
# transmission         0
# VIN                  0
# drive                0
# size                 0
# type                 0
# paint_color      31462
# image_url            0
# description         42
# state                0
# lat               1408
# long              1408
# posting_date         0
# dtype: int64

# %%
vehicles.to_csv('vehicles')

# %%
vehicles['year'] =vehicles['year'].astype(int)
# Out:
# <ipython-input-38-40deee811f1f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles['year'] =vehicles['year'].astype(int)

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131021 entries, 0 to 458211
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    131021 non-null  int64
#  1   id            131021 non-null  int64
#  2   url           131021 non-null  object
#  3   region        131021 non-null  object
#  4   region_url    131021 non-null  object
#  5   price         131021 non-null  int64
#  6   year          131021 non-null  int32
#  7   manufacturer  131021 non-null  object
#  8   model         130507 non-null  object
#  9   condition     70805 non-null   object
#  10  cylinders     131021 non-null  object
#  11  fuel          131021 non-null  object
#  12  odometer      127844 non-null  float64
#  13  title_status  129700 non-null  object
#  14  transmission  131021 non-null  object
#  15  VIN           131021 non-null  object
#  16  drive         131021 non-null  object
# ...

# %%
dummy = vehicles.groupby(['year','model'])['odometer'].median()
dummy.head()
# Out:
# year  model
# 1995  1500                 204951.0
#       1500 laramie slt      78268.0
#       1500 sierra               NaN
#       1800 ud rollback     515737.0
#       1995 Corvette ZR1     59600.0
# Name: odometer, dtype: float64

# %%
year_model_median_odometer_reading = dict(vehicles.groupby(['year','model'])['odometer'].median())

# %%
year_model_median_odometer_reading
# Out:
# {(1995, '1500'): 204951.0,
#  (1995, '1500 laramie slt'): 78268.0,
#  (1995, '1500 sierra'): nan,
#  (1995, '1800 ud rollback'): 515737.0,
#  (1995, '1995 Corvette ZR1'): 59600.0,
#  (1995, '240sx s14'): 140000.0,
#  (1995, '2500'): 267000.0,
#  (1995, '2500 club coupe'): 144945.0,
#  (1995, '3 series l'): 94696.0,
#  (1995, '3000gt'): 73324.0,
#  (1995, '325i'): 170000.0,
#  (1995, '325ic'): 94449.0,
#  (1995, '5 series 540i'): 98865.0,
#  (1995, '63,701'): nan,
#  (1995, '740i'): 89960.0,
#  (1995, '850'): 249007.0,
#  (1995, '850 glt sedan heated leather 2 owners sun roof'): 33748.0,
#  (1995, '911'): 71147.0,
#  (1995, '95 F-250 X-CAB'): 244415.0,
#  (1995, '95 linc towncar signature series'): 19350.0,
#  (1995, 'Bluebird TC2000'): 42024.0,
#  (1995, 'Internation Navi Star 4700'): 249873.0,
#  (1995, 'International 4900 dump truck'): 79302.0,
#  (1995, 'International Dump Truck'): 74642.0,
#  (1995, 'K2500 SLE Z71'): 4566.0,
#  (1995, 'Volo 850'): 177424.0,
# ...

# %%
#vehicles['cylinders'] = vehicles['model'].map(dup_dict_cylinders)
vehicles['odometer'] = vehicles.odometer.fillna(vehicles[['year','model']].map(dup_dict_cylinders))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-0fa20dc86c2f> in <module>
#       1 #vehicles['cylinders'] = vehicles['model'].map(dup_dict_cylinders)
# ----> 2 vehicles['odometer'] = vehicles.odometer.fillna(vehicles[['year','model']].map(dup_dict_cylinders))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'map'
